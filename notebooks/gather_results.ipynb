# %%
import os
import json
import math
import numpy as np
import pandas as pd

# %%
ROOT_DIR="/mnt/ps/home/CORP/yassir.elmesbahi"
PROJECT_DIR=f"{ROOT_DIR}/project/safe-setup-models"
MODELS_DIR=f"{ROOT_DIR}/sandbox/models"
N_SAMPLES=10000

# %%
global_dic = {}
for model_name in os.listdir(MODELS_DIR):
    #if "SMILES" in model_name:
    #    continue
    model_path = os.path.join(MODELS_DIR, model_name)
    if not os.path.isdir(model_path):
        continue
    eval_path = os.path.join(model_path, "eval_results.json")
    test_path = os.path.join(os.path.join(model_path, "evaluation"), "eval_results.json")
    sampling_path = os.path.join(os.path.join(model_path, "sampling"), f"results_{N_SAMPLES}.json")
    #if not os.path.isdir(dirpath):
    #    continue
    print(f"############ Processing model saved in {model_path}")
    global_dic[model_name] = {"eval":{}, "test":{}, "sampling":{}}
    try:
        with open(eval_path, "r") as fp:
            global_dic[model_name]["eval"] = json.load(fp)
    except Exception as err:
        print(f"Unexpected {err=}, {type(err)=}: file '{eval_path}' for model '{model_name}'")
    try:
        with open(test_path, "r") as fp:
            global_dic[model_name]["test"] = json.load(fp)
    except Exception as err:
        print(f"Unexpected {err=}, {type(err)=}: file '{test_path}' for model '{model_name}'")
    try:
        with open(sampling_path, "r") as fp:
            global_dic[model_name]["sampling"] = json.load(fp)
    except Exception as err:
        print(f"Unexpected {err=}, {type(err)=}: file '{sampling_path}' for model '{model_name}'")

print(f"Number of entries in global_dic: {len(global_dic)}")
# Out:
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-brics
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-rotatable_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-recap_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-hr
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-rotatable_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-brics_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-mmpa_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-mmpa
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_smiles
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-hr_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-recap_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-brics_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-brics_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-brics_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-rotatable_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-mmpa
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-hr_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-mmpa
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-brics_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-recap
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-hr_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-rotatable_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-mmpa_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-hr_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-recap
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-mmpa_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-hr_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-hr_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_smiles_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_smiles
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-recap_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-rotatable_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-brics
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-rotatable
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_smiles_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-hr
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-mmpa_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-rotatable_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-rotatable_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-mmpa_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-rotatable_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_smiles
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-brics_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-brics
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-rotatable
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-recap_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-recap_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_smiles_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-recap_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-recap_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-mmpa_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-mmpa_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-mmpa_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-rotatable_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-hr_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_safe-recap_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-brics_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/llama_smiles_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_smiles_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-recap_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-hr
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-brics_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-hr_10000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-hr_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-brics_augmentation_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-mmpa_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/jamba_safe-rotatable
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_smiles_100000
# ############ Processing model saved in /mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models/gpt2_safe-recap
# Number of entries in global_dic: 69

# %%
global_dic
# Out:
# {'jamba_safe-brics': {'eval': {'epoch': 9.502993442934525,
#    'eval_accuracy': 0.8206538577534228,
#    'eval_fragmented': 0.9035514018691588,
#    'eval_loss': 0.5065621733665466,
#    'eval_runtime': 340.6609,
#    'eval_samples_per_second': 564.899,
#    'eval_steps_per_second': 4.415,
#    'eval_validity': 0.013900508732637356,
#    'perplexity': 1.659576042004726},
#   'test': {'eval_accuracy': 0.8206703339229323,
#    'eval_fragmented': 0.895741556534508,
#    'eval_loss': 0.5064355731010437,
#    'eval_runtime': 740.8956,
#    'eval_samples_per_second': 519.541,
#    'eval_steps_per_second': 2.03,
#    'eval_validity': 0.014153369738599108,
#    'perplexity': 1.659365952536158},
#   'sampling': {'fragmentation_percentage': 0.1643339165208698,
#    'fragmentation_size': 31.84,
#    'fragmentation_number': 1.17,
#    'novelty': 0.9179384538403803,
#    'validity': 0.8002,
#    'uniqueness': 0.9990002499375156,
#    'internal_diversity': 0.8473307617177313}},
#  'llama_safe-rotatable_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8037078343899194,
#    'eval_fragmented': 0.9671658986175116,
#    'eval_loss': 0.572909951210022,
#    'eval_runtime': 640.2793,
#    'eval_samples_per_second': 302.12,
#    'eval_steps_per_second': 1.181,
#    'eval_validity': 0.017948625162194157,
#    'perplexity': 1.7734201162269954},
#   'test': {'eval_accuracy': 0.8036196851962456,
#    'eval_fragmented': 0.9647495361781077,
#    'eval_loss': 0.5726862549781799,
#    'eval_runtime': 1392.7921,
#    'eval_samples_per_second': 277.739,
#    'eval_steps_per_second': 1.086,
#    'eval_validity': 0.018113806510319724,
#    'perplexity': 1.7730234531971891},
#   'sampling': {'fragmentation_percentage': 0.15030885380919698,
#    'fragmentation_size': 32.57,
#    'fragmentation_number': 1.15,
#    'novelty': 0.9428080229226361,
#    'validity': 0.8742,
#    'uniqueness': 0.9980553649050561,
#    'internal_diversity': 0.8498663121681926}},
#  'jamba_safe-recap_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.730570934846456,
#    'eval_fragmented': 0.8819875776397516,
#    'eval_loss': 0.7823565602302551,
#    'eval_runtime': 330.8118,
#    'eval_samples_per_second': 576.201,
#    'eval_steps_per_second': 2.252,
#    'eval_validity': 0.0016892778075062692,
#    'perplexity': 2.1866190983113802},
#   'test': {'eval_accuracy': 0.7305742948735524,
#    'eval_fragmented': 0.8386605783866058,
#    'eval_loss': 0.7818681001663208,
#    'eval_runtime': 785.6951,
#    'eval_samples_per_second': 485.173,
#    'eval_steps_per_second': 1.896,
#    'eval_validity': 0.0017235137645003383,
#    'perplexity': 2.185551283020613},
#   'sampling': {'fragmentation_percentage': 0.09594755661501787,
#    'fragmentation_size': 30.69,
#    'fragmentation_number': 1.1,
#    'novelty': 0.9234449760765551,
#    'validity': 0.1678,
#    'uniqueness': 0.9964243146603099,
#    'internal_diversity': 0.8348261828764776}},
#  'gpt2_safe-hr': {'eval': {'epoch': 9.441087613293051,
#    'eval_accuracy': 0.7909591203234765,
#    'eval_fragmented': 0.9925148028153279,
#    'eval_loss': 0.613968551158905,
#    'eval_runtime': 426.8028,
#    'eval_samples_per_second': 453.781,
#    'eval_steps_per_second': 3.547,
#    'eval_validity': 0.04621659997418356,
#    'perplexity': 1.84774975697663},
#   'test': {'eval_accuracy': 0.791001845622781,
#    'eval_fragmented': 0.9915444058685183,
#    'eval_loss': 0.6140081882476807,
#    'eval_runtime': 998.1177,
#    'eval_samples_per_second': 388.061,
#    'eval_steps_per_second': 1.517,
#    'eval_validity': 0.046105269136733185,
#    'perplexity': 1.8478229978493002},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'llama_safe-rotatable_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7397331794109206,
#    'eval_fragmented': 0.9743983614951357,
#    'eval_loss': 0.7596818804740906,
#    'eval_runtime': 580.1254,
#    'eval_samples_per_second': 333.447,
#    'eval_steps_per_second': 1.303,
#    'eval_validity': 0.010096101653734214,
#    'perplexity': 2.1375961012646303},
#   'test': {'eval_accuracy': 0.7398970503087388,
#    'eval_fragmented': 0.9703100367840253,
#    'eval_loss': 0.7591691017150879,
#    'eval_runtime': 1377.1356,
#    'eval_samples_per_second': 280.896,
#    'eval_steps_per_second': 1.098,
#    'eval_validity': 0.009838896471853414,
#    'perplexity': 2.136500268372502},
#   'sampling': {'fragmentation_percentage': 0.29425682942568293,
#    'fragmentation_size': 29.12,
#    'fragmentation_number': 1.3,
#    'novelty': 0.9849429984942999,
#    'validity': 0.4649,
#    'uniqueness': 1.0,
#    'internal_diversity': 0.8473218920140542}},
#  'gpt2_safe-brics_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7500034614504839,
#    'eval_fragmented': 0.8733370288248337,
#    'eval_loss': 0.6812206506729126,
#    'eval_runtime': 851.3496,
#    'eval_samples_per_second': 226.04,
#    'eval_steps_per_second': 1.767,
#    'eval_validity': 0.0093757389761007,
#    'perplexity': 1.9762886185381896},
#   'test': {'eval_accuracy': 0.7475067248181708,
#    'eval_fragmented': 0.8606613454960091,
#    'eval_loss': 0.6832821369171143,
#    'eval_runtime': 989.3985,
#    'eval_samples_per_second': 389.051,
#    'eval_steps_per_second': 1.52,
#    'eval_validity': 0.011391799982334267,
#    'perplexity': 1.9803669125690981},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': 57.0,
#    'fragmentation_number': 1.0,
#    'novelty': 1.0,
#    'validity': 0.0001,
#    'uniqueness': 1.0,
#    'internal_diversity': 0.0}},
#  'llama_safe-mmpa_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7429134200836747,
#    'eval_fragmented': 0.9821882951653944,
#    'eval_loss': 0.7743914127349854,
#    'eval_runtime': 639.5347,
#    'eval_samples_per_second': 302.817,
#    'eval_steps_per_second': 1.184,
#    'eval_validity': 0.010146543978684513,
#    'perplexity': 2.169271534346049},
#   'test': {'eval_accuracy': 0.7429956339799393,
#    'eval_fragmented': 0.9861218195836546,
#    'eval_loss': 0.7741088271141052,
#    'eval_runtime': 2066.3034,
#    'eval_samples_per_second': 187.44,
#    'eval_steps_per_second': 0.732,
#    'eval_validity': 0.010046268086380865,
#    'perplexity': 2.1686586160076917},
#   'sampling': {'fragmentation_percentage': 0.42041837198726695,
#    'fragmentation_size': 26.85,
#    'fragmentation_number': 1.44,
#    'novelty': 0.9927206551410374,
#    'validity': 0.4398,
#    'uniqueness': 0.9995452478399273,
#    'internal_diversity': 0.846899571191454}},
#  'jamba_safe-mmpa': {'eval': {'epoch': 9.441979038806533,
#    'eval_accuracy': 0.7978925034524821,
#    'eval_fragmented': 0.9764679515912147,
#    'eval_loss': 0.5943283438682556,
#    'eval_runtime': 362.4575,
#    'eval_samples_per_second': 534.303,
#    'eval_steps_per_second': 4.174,
#    'eval_validity': 0.02304014210325206,
#    'perplexity': 1.8118136204664255},
#   'test': {'eval_accuracy': 0.7979639227984127,
#    'eval_fragmented': 0.9786310135984458,
#    'eval_loss': 0.5941793918609619,
#    'eval_runtime': 766.8687,
#    'eval_samples_per_second': 505.051,
#    'eval_steps_per_second': 1.973,
#    'eval_validity': 0.022594420977619878,
#    'perplexity': 1.8115437672889},
#   'sampling': {'fragmentation_percentage': 0.33311240721102864,
#    'fragmentation_size': 28.98,
#    'fragmentation_number': 1.35,
#    'novelty': 0.9689572830989652,
#    'validity': 0.7544,
#    'uniqueness': 0.999204665959703,
#    'internal_diversity': 0.8515864526861439}},
#  'gpt2_smiles': {'eval': {'epoch': 9.440196356084206,
#    'eval_accuracy': 0.7922144111630198,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5523082613945007,
#    'eval_runtime': 405.6187,
#    'eval_samples_per_second': 477.532,
#    'eval_steps_per_second': 3.733,
#    'eval_validity': 0.00775958202544193,
#    'perplexity': 1.7372584398975301},
#   'test': {'eval_accuracy': 0.7924808284000423,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5521002411842346,
#    'eval_runtime': 960.045,
#    'eval_samples_per_second': 403.514,
#    'eval_steps_per_second': 1.577,
#    'eval_validity': 0.00808225260201553,
#    'perplexity': 1.7368970926166476},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.0013,
#    'uniqueness': 1.0,
#    'internal_diversity': 1.3914257811498132e-06}},
#  'llama_safe-hr_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.7959980575212054,
#    'eval_fragmented': 0.9895154723127035,
#    'eval_loss': 0.6102568507194519,
#    'eval_runtime': 586.6079,
#    'eval_samples_per_second': 330.161,
#    'eval_steps_per_second': 1.29,
#    'eval_validity': 0.05072415128436814,
#    'perplexity': 1.8409041756244533},
#   'test': {'eval_accuracy': 0.7960056648993905,
#    'eval_fragmented': 0.9879963989196759,
#    'eval_loss': 0.6101857423782349,
#    'eval_runtime': 1370.8425,
#    'eval_samples_per_second': 282.55,
#    'eval_steps_per_second': 1.104,
#    'eval_validity': 0.051619932305960535,
#    'perplexity': 1.8407732766362452},
#   'sampling': {'fragmentation_percentage': 0.25387803433984607,
#    'fragmentation_size': 30.45,
#    'fragmentation_number': 1.26,
#    'novelty': 0.9660976766239924,
#    'validity': 0.8445,
#    'uniqueness': 0.9989342806394316,
#    'internal_diversity': 0.8541833148328358}},
#  'gpt2_safe-recap_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8048277430773974,
#    'eval_fragmented': 0.7742214532871973,
#    'eval_loss': 0.5383830666542053,
#    'eval_runtime': 453.9923,
#    'eval_samples_per_second': 419.862,
#    'eval_steps_per_second': 1.641,
#    'eval_validity': 0.006064612253034929,
#    'perplexity': 1.7132344354864044},
#   'test': {'eval_accuracy': 0.8048835179827306,
#    'eval_fragmented': 0.7955243527863097,
#    'eval_loss': 0.5386325716972351,
#    'eval_runtime': 948.7428,
#    'eval_samples_per_second': 401.793,
#    'eval_steps_per_second': 1.57,
#    'eval_validity': 0.005978520349004979,
#    'perplexity': 1.7136619494491774},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'gpt2_safe-brics_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7277055255771723,
#    'eval_fragmented': 0.9293544457978076,
#    'eval_loss': 0.8049032688140869,
#    'eval_runtime': 396.6423,
#    'eval_samples_per_second': 485.17,
#    'eval_steps_per_second': 1.896,
#    'eval_validity': 0.004266286979250568,
#    'perplexity': 2.2364801509790886},
#   'test': {'eval_accuracy': 0.7278778194112118,
#    'eval_fragmented': 0.9259723964868256,
#    'eval_loss': 0.8042059540748596,
#    'eval_runtime': 988.058,
#    'eval_samples_per_second': 389.578,
#    'eval_steps_per_second': 1.522,
#    'eval_validity': 0.004141055683430062,
#    'perplexity': 2.234921164021285},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'llama_safe-brics_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7595328894468107,
#    'eval_fragmented': 0.9638771824202288,
#    'eval_loss': 0.7054733037948608,
#    'eval_runtime': 563.0995,
#    'eval_samples_per_second': 341.75,
#    'eval_steps_per_second': 1.335,
#    'eval_validity': 0.008631306543891831,
#    'perplexity': 2.024804805961814},
#   'test': {'eval_accuracy': 0.7596260617483264,
#    'eval_fragmented': 0.9710793082886107,
#    'eval_loss': 0.7049030065536499,
#    'eval_runtime': 1331.4605,
#    'eval_samples_per_second': 289.101,
#    'eval_steps_per_second': 1.13,
#    'eval_validity': 0.008713363087970155,
#    'perplexity': 2.023650394577085},
#   'sampling': {'fragmentation_percentage': 0.2981180496150556,
#    'fragmentation_size': 28.88,
#    'fragmentation_number': 1.31,
#    'novelty': 0.9708404802744426,
#    'validity': 0.4676,
#    'uniqueness': 0.9974337040205303,
#    'internal_diversity': 0.8433628565993143}},
#  'llama_safe-brics_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7593535543832777,
#    'eval_fragmented': 0.8603066439522998,
#    'eval_loss': 0.6506363749504089,
#    'eval_runtime': 1146.5078,
#    'eval_samples_per_second': 167.848,
#    'eval_steps_per_second': 1.312,
#    'eval_validity': 0.015253766017103968,
#    'perplexity': 1.9167602191674886},
#   'test': {'eval_accuracy': 0.7572362222195161,
#    'eval_fragmented': 0.8284505718314272,
#    'eval_loss': 0.6512003540992737,
#    'eval_runtime': 1327.9412,
#    'eval_samples_per_second': 289.867,
#    'eval_steps_per_second': 1.133,
#    'eval_validity': 0.016582408047261032,
#    'perplexity': 1.917841536856126},
#   'sampling': {'fragmentation_percentage': 0.19298858607034708,
#    'fragmentation_size': 31.85,
#    'fragmentation_number': 1.2,
#    'novelty': 0.9527696793002915,
#    'validity': 0.8586,
#    'uniqueness': 0.9987188446307943,
#    'internal_diversity': 0.8529956475950433}},
#  'gpt2_safe-rotatable_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.7975922447453323,
#    'eval_fragmented': 0.9628589263420724,
#    'eval_loss': 0.5826980471611023,
#    'eval_runtime': 421.93,
#    'eval_samples_per_second': 458.467,
#    'eval_steps_per_second': 1.792,
#    'eval_validity': 0.01656318980981281,
#    'perplexity': 1.7908637532144223},
#   'test': {'eval_accuracy': 0.7975712835308691,
#    'eval_fragmented': 0.967860422405877,
#    'eval_loss': 0.5824124813079834,
#    'eval_runtime': 975.1976,
#    'eval_samples_per_second': 396.67,
#    'eval_steps_per_second': 1.55,
#    'eval_validity': 0.016891053480580717,
#    'perplexity': 1.7903524166925158},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'gpt2_safe-mmpa': {'eval': {'epoch': 9.441979038806533,
#    'eval_accuracy': 0.8003037898950939,
#    'eval_fragmented': 0.9866117404737385,
#    'eval_loss': 0.5889895558357239,
#    'eval_runtime': 415.9053,
#    'eval_samples_per_second': 465.64,
#    'eval_steps_per_second': 3.638,
#    'eval_validity': 0.03008334107878675,
#    'perplexity': 1.8021665064547399},
#   'test': {'eval_accuracy': 0.8001806218053085,
#    'eval_fragmented': 0.9828511124791135,
#    'eval_loss': 0.5888725519180298,
#    'eval_runtime': 989.6581,
#    'eval_samples_per_second': 391.355,
#    'eval_steps_per_second': 1.529,
#    'eval_validity': 0.029359063071250788,
#    'perplexity': 1.8019556582484213},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'llama_safe-hr_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.6874576694951992,
#    'eval_fragmented': 0.9437476945776466,
#    'eval_loss': 0.8736223578453064,
#    'eval_runtime': 1208.6074,
#    'eval_samples_per_second': 160.246,
#    'eval_steps_per_second': 1.253,
#    'eval_validity': 0.01399807403850374,
#    'perplexity': 2.3955727776034754},
#   'test': {'eval_accuracy': 0.6846963189686975,
#    'eval_fragmented': 0.9732060717571297,
#    'eval_loss': 0.8720607161521912,
#    'eval_runtime': 1328.847,
#    'eval_samples_per_second': 291.479,
#    'eval_steps_per_second': 1.139,
#    'eval_validity': 0.022451081891199,
#    'perplexity': 2.3918346708264604},
#   'sampling': {'fragmentation_percentage': 0.3507380749054532,
#    'fragmentation_size': 28.93,
#    'fragmentation_number': 1.37,
#    'novelty': 0.9918242830994509,
#    'validity': 0.8197,
#    'uniqueness': 0.999756008295718,
#    'internal_diversity': 0.8563870098290873}},
#  'llama_safe-mmpa': {'eval': {'epoch': 9.441979038806533,
#    'eval_accuracy': 0.8113404229868774,
#    'eval_fragmented': 0.9862588652482269,
#    'eval_loss': 0.554584801197052,
#    'eval_runtime': 589.2723,
#    'eval_samples_per_second': 328.646,
#    'eval_steps_per_second': 2.568,
#    'eval_validity': 0.034947485825820246,
#    'perplexity': 1.7412178830882563},
#   'test': {'eval_accuracy': 0.8112465466252634,
#    'eval_fragmented': 0.9867544768388338,
#    'eval_loss': 0.5545090436935425,
#    'eval_runtime': 1338.5338,
#    'eval_samples_per_second': 289.352,
#    'eval_steps_per_second': 1.13,
#    'eval_validity': 0.034892127195926756,
#    'perplexity': 1.7410859777648395},
#   'sampling': {'fragmentation_percentage': 0.22980684811237928,
#    'fragmentation_size': 31.0,
#    'fragmentation_number': 1.24,
#    'novelty': 0.9526633717737507,
#    'validity': 0.9112,
#    'uniqueness': 0.9992317822651449,
#    'internal_diversity': 0.8517329990510718}},
#  'gpt2_safe-brics_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8146093781820728,
#    'eval_fragmented': 0.9287144573488186,
#    'eval_loss': 0.5262125134468079,
#    'eval_runtime': 405.1435,
#    'eval_samples_per_second': 474.99,
#    'eval_steps_per_second': 1.856,
#    'eval_validity': 0.01297554030108242,
#    'perplexity': 1.692509795613303},
#   'test': {'eval_accuracy': 0.814752676878111,
#    'eval_fragmented': 0.9279794790844514,
#    'eval_loss': 0.5257709622383118,
#    'eval_runtime': 955.4847,
#    'eval_samples_per_second': 402.859,
#    'eval_steps_per_second': 1.574,
#    'eval_validity': 0.013166167003527952,
#    'perplexity': 1.6917626308355533},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'jamba_safe-recap': {'eval': {'epoch': 9.596928982725528,
#    'eval_accuracy': 0.8090152376397923,
#    'eval_fragmented': 0.8719912472647703,
#    'eval_loss': 0.5247061252593994,
#    'eval_runtime': 348.8888,
#    'eval_samples_per_second': 546.346,
#    'eval_steps_per_second': 4.271,
#    'eval_validity': 0.004795030795219659,
#    'perplexity': 1.6899621382123884},
#   'test': {'eval_accuracy': 0.8090877925672323,
#    'eval_fragmented': 0.8525219298245614,
#    'eval_loss': 0.52485191822052,
#    'eval_runtime': 728.1178,
#    'eval_samples_per_second': 523.539,
#    'eval_steps_per_second': 2.046,
#    'eval_validity': 0.0047849149261013964,
#    'perplexity': 1.690208540758142},
#   'sampling': {'fragmentation_percentage': 0.060825676200336486,
#    'fragmentation_size': 33.93,
#    'fragmentation_number': 1.06,
#    'novelty': 0.8752919802751103,
#    'validity': 0.7727,
#    'uniqueness': 0.9972822570208361,
#    'internal_diversity': 0.8453734589014174}},
#  'gpt2_safe-hr_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.7880935941426553,
#    'eval_fragmented': 0.9921697684975034,
#    'eval_loss': 0.6247559785842896,
#    'eval_runtime': 412.3333,
#    'eval_samples_per_second': 469.705,
#    'eval_steps_per_second': 1.836,
#    'eval_validity': 0.04549890280108429,
#    'perplexity': 1.8677901210279788},
#   'test': {'eval_accuracy': 0.7880751853201966,
#    'eval_fragmented': 0.9925582460358349,
#    'eval_loss': 0.6247715353965759,
#    'eval_runtime': 986.2946,
#    'eval_samples_per_second': 392.713,
#    'eval_steps_per_second': 1.535,
#    'eval_validity': 0.045100960160689436,
#    'perplexity': 1.8678191781142992},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'llama_safe-rotatable_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7253103546903759,
#    'eval_fragmented': 0.8818233781080309,
#    'eval_loss': 0.7545694708824158,
#    'eval_runtime': 1257.9217,
#    'eval_samples_per_second': 153.778,
#    'eval_steps_per_second': 1.202,
#    'eval_validity': 0.01808974561133672,
#    'perplexity': 2.12669572179735},
#   'test': {'eval_accuracy': 0.7278510464889415,
#    'eval_fragmented': 0.9102771596196642,
#    'eval_loss': 0.7518213391304016,
#    'eval_runtime': 1315.5116,
#    'eval_samples_per_second': 294.054,
#    'eval_steps_per_second': 1.149,
#    'eval_validity': 0.025556313852008107,
#    'perplexity': 2.1208593050516567},
#   'sampling': {'fragmentation_percentage': 0.2617650442986998,
#    'fragmentation_size': 30.27,
#    'fragmentation_number': 1.27,
#    'novelty': 0.9780181839106917,
#    'validity': 0.8691,
#    'uniqueness': 0.999769876884133,
#    'internal_diversity': 0.8560573808243866}},
#  'jamba_safe-mmpa_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7110457259403392,
#    'eval_fragmented': 0.8660836294069418,
#    'eval_loss': 0.8220663666725159,
#    'eval_runtime': 690.118,
#    'eval_samples_per_second': 280.622,
#    'eval_steps_per_second': 2.192,
#    'eval_validity': 0.009449945505916869,
#    'perplexity': 2.275196373438138},
#   'test': {'eval_accuracy': 0.7039582332064526,
#    'eval_fragmented': 0.8852311566828567,
#    'eval_loss': 0.8256360292434692,
#    'eval_runtime': 744.2716,
#    'eval_samples_per_second': 520.385,
#    'eval_steps_per_second': 2.033,
#    'eval_validity': 0.014352918091028328,
#    'perplexity': 2.283332569872294},
#   'sampling': {'fragmentation_percentage': 0.3671600793529681,
#    'fragmentation_size': 28.85,
#    'fragmentation_number': 1.39,
#    'novelty': 0.9822981840378453,
#    'validity': 0.6553,
#    'uniqueness': 1.0,
#    'internal_diversity': 0.8507193402384916}},
#  'jamba_safe-hr_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.7823525139484231,
#    'eval_fragmented': 0.9864783653846154,
#    'eval_loss': 0.6429221630096436,
#    'eval_runtime': 375.2068,
#    'eval_samples_per_second': 516.182,
#    'eval_steps_per_second': 2.018,
#    'eval_validity': 0.03436685168452304,
#    'perplexity': 1.9020308105315658},
#   'test': {'eval_accuracy': 0.7824935961361583,
#    'eval_fragmented': 0.9843889384478145,
#    'eval_loss': 0.6425184011459351,
#    'eval_runtime': 760.6912,
#    'eval_samples_per_second': 509.183,
#    'eval_steps_per_second': 1.99,
#    'eval_validity': 0.034729985464628445,
#    'perplexity': 1.901262998043806},
#   'sampling': {'fragmentation_percentage': 0.35348125478194337,
#    'fragmentation_size': 28.64,
#    'fragmentation_number': 1.37,
#    'novelty': 0.979482468228449,
#    'validity': 0.6535,
#    'uniqueness': 0.9993879112471309,
#    'internal_diversity': 0.8558887772530227}},
#  'llama_safe-recap': {'eval': {'epoch': 9.596928982725528,
#    'eval_accuracy': 0.8196685760061011,
#    'eval_fragmented': 0.8069275176395125,
#    'eval_loss': 0.48990973830223083,
#    'eval_runtime': 607.8686,
#    'eval_samples_per_second': 313.578,
#    'eval_steps_per_second': 2.451,
#    'eval_validity': 0.008178832614603334,
#    'perplexity': 1.6321688909712517},
#   'test': {'eval_accuracy': 0.8197008178548769,
#    'eval_fragmented': 0.7882882882882883,
#    'eval_loss': 0.49009066820144653,
#    'eval_runtime': 1281.5342,
#    'eval_samples_per_second': 297.454,
#    'eval_steps_per_second': 1.163,
#    'eval_validity': 0.008153243196449089,
#    'perplexity': 1.6324642258408466},
#   'sampling': {'fragmentation_percentage': 0.029515808091974353,
#    'fragmentation_size': 35.0,
#    'fragmentation_number': 1.03,
#    'novelty': 0.866371191135734,
#    'validity': 0.9046,
#    'uniqueness': 0.9976785319478222,
#    'internal_diversity': 0.846619527657732}},
#  'llama_safe-mmpa_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7172332013070873,
#    'eval_fragmented': 0.9111433305716653,
#    'eval_loss': 0.8007954955101013,
#    'eval_runtime': 1148.2768,
#    'eval_samples_per_second': 168.654,
#    'eval_steps_per_second': 1.318,
#    'eval_validity': 0.012469072670829912,
#    'perplexity': 2.2273120406711246},
#   'test': {'eval_accuracy': 0.7112117270436108,
#    'eval_fragmented': 0.941623676350801,
#    'eval_loss': 0.7987440824508667,
#    'eval_runtime': 1321.3676,
#    'eval_samples_per_second': 293.111,
#    'eval_steps_per_second': 1.145,
#    'eval_validity': 0.01901845559606308,
#    'perplexity': 2.222747587054494},
#   'sampling': {'fragmentation_percentage': 0.3249652938454419,
#    'fragmentation_size': 29.64,
#    'fragmentation_number': 1.34,
#    'novelty': 0.9813722087238227,
#    'validity': 0.8644,
#    'uniqueness': 0.9998843128181397,
#    'internal_diversity': 0.8533800649033451}},
#  'jamba_safe-hr_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7233798040619926,
#    'eval_fragmented': 0.9861651534803286,
#    'eval_loss': 0.8342931270599365,
#    'eval_runtime': 400.6278,
#    'eval_samples_per_second': 483.429,
#    'eval_steps_per_second': 1.89,
#    'eval_validity': 0.023885374983864723,
#    'perplexity': 2.303185413291219},
#   'test': {'eval_accuracy': 0.7235003834361986,
#    'eval_fragmented': 0.9872611464968153,
#    'eval_loss': 0.833930253982544,
#    'eval_runtime': 747.307,
#    'eval_samples_per_second': 518.302,
#    'eval_steps_per_second': 2.026,
#    'eval_validity': 0.02350960806132223,
#    'perplexity': 2.3023498009322756},
#   'sampling': {'fragmentation_percentage': 0.41902136457615435,
#    'fragmentation_size': 26.46,
#    'fragmentation_number': 1.44,
#    'novelty': 0.993103448275862,
#    'validity': 0.1451,
#    'uniqueness': 0.9993108201240524,
#    'internal_diversity': 0.8516596253713682}},
#  'jamba_safe-hr_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.6817979596069929,
#    'eval_fragmented': 0.9142612174907117,
#    'eval_loss': 0.8947930932044983,
#    'eval_runtime': 683.0471,
#    'eval_samples_per_second': 283.546,
#    'eval_steps_per_second': 2.217,
#    'eval_validity': 0.009033430664095276,
#    'perplexity': 2.446829471438723},
#   'test': {'eval_accuracy': 0.6774662388064684,
#    'eval_fragmented': 0.913623934373492,
#    'eval_loss': 0.9017163515090942,
#    'eval_runtime': 855.4814,
#    'eval_samples_per_second': 452.764,
#    'eval_steps_per_second': 1.77,
#    'eval_validity': 0.016050871218673435,
#    'perplexity': 2.463828279568416},
#   'sampling': {'fragmentation_percentage': 0.38238645612892724,
#    'fragmentation_size': 28.07,
#    'fragmentation_number': 1.4,
#    'novelty': 0.9938130901986324,
#    'validity': 0.6143,
#    'uniqueness': 0.9998372130880677,
#    'internal_diversity': 0.8562283522141899}},
#  'gpt2_smiles_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7246104552287069,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.77256840467453,
#    'eval_runtime': 399.0266,
#    'eval_samples_per_second': 485.421,
#    'eval_steps_per_second': 1.897,
#    'eval_validity': 0.003262844870312242,
#    'perplexity': 2.1653205372975677},
#   'test': {'eval_accuracy': 0.7247162259992019,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.7719544172286987,
#    'eval_runtime': 926.1432,
#    'eval_samples_per_second': 418.285,
#    'eval_steps_per_second': 1.635,
#    'eval_validity': 0.0031492648273583348,
#    'perplexity': 2.163991465729848},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.0015,
#    'uniqueness': 0.9999,
#    'internal_diversity': 1.7635888672762334e-06}},
#  'jamba_smiles': {'eval': {'epoch': 9.440196356084206,
#    'eval_accuracy': 0.7941948755377888,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5475282669067383,
#    'eval_runtime': 347.6211,
#    'eval_samples_per_second': 557.204,
#    'eval_steps_per_second': 4.355,
#    'eval_validity': 0.009225797125392367,
#    'perplexity': 1.7289741692884095},
#   'test': {'eval_accuracy': 0.7944178614930572,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5473328828811646,
#    'eval_runtime': 831.3677,
#    'eval_samples_per_second': 465.97,
#    'eval_steps_per_second': 1.821,
#    'eval_validity': 0.0092412853130679,
#    'perplexity': 1.7286363883546747},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.9312,
#    'uniqueness': 0.9985,
#    'internal_diversity': 0.7313520512911988}},
#  'gpt2_safe-recap_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.6995382388693462,
#    'eval_fragmented': 0.7256317689530686,
#    'eval_loss': 0.8695541024208069,
#    'eval_runtime': 420.0669,
#    'eval_samples_per_second': 453.771,
#    'eval_steps_per_second': 1.774,
#    'eval_validity': 0.0014531986108050825,
#    'perplexity': 2.3858467730060346},
#   'test': {'eval_accuracy': 0.6997343905784013,
#    'eval_fragmented': 0.7879310344827586,
#    'eval_loss': 0.868876039981842,
#    'eval_runtime': 914.3777,
#    'eval_samples_per_second': 416.893,
#    'eval_steps_per_second': 1.63,
#    'eval_validity': 0.0015215190006243474,
#    'perplexity': 2.3842295682689896},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'jamba_safe-rotatable_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7180200287466767,
#    'eval_fragmented': 0.8748904469763366,
#    'eval_loss': 0.7794715762138367,
#    'eval_runtime': 686.4959,
#    'eval_samples_per_second': 281.78,
#    'eval_steps_per_second': 2.202,
#    'eval_validity': 0.011797884962866649,
#    'perplexity': 2.1803198281787184},
#   'test': {'eval_accuracy': 0.7203617316363435,
#    'eval_fragmented': 0.9044183949504058,
#    'eval_loss': 0.7768070101737976,
#    'eval_runtime': 847.3353,
#    'eval_samples_per_second': 456.528,
#    'eval_steps_per_second': 1.784,
#    'eval_validity': 0.020068143276667907,
#    'perplexity': 2.174517955177745},
#   'sampling': {'fragmentation_percentage': 0.3040367220197111,
#    'fragmentation_size': 29.37,
#    'fragmentation_number': 1.32,
#    'novelty': 0.9831172339276067,
#    'validity': 0.7407,
#    'uniqueness': 0.9995949777237748,
#    'internal_diversity': 0.8560692430192571}},
#  'gpt2_safe-brics': {'eval': {'epoch': 9.502993442934525,
#    'eval_accuracy': 0.8174843130246631,
#    'eval_fragmented': 0.9408885542168675,
#    'eval_loss': 0.5154023766517639,
#    'eval_runtime': 402.5328,
#    'eval_samples_per_second': 478.07,
#    'eval_steps_per_second': 3.736,
#    'eval_validity': 0.01380177614724666,
#    'perplexity': 1.6743120703591894},
#   'test': {'eval_accuracy': 0.8175814711914341,
#    'eval_fragmented': 0.9295800476801761,
#    'eval_loss': 0.5151990056037903,
#    'eval_runtime': 949.7983,
#    'eval_samples_per_second': 405.271,
#    'eval_steps_per_second': 1.583,
#    'eval_validity': 0.014166359248271096,
#    'perplexity': 1.6739715983810504},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'llama_safe-rotatable': {'eval': {'epoch': 9.454476694714948,
#    'eval_accuracy': 0.8134191863852582,
#    'eval_fragmented': 0.9688423314531291,
#    'eval_loss': 0.5347084999084473,
#    'eval_runtime': 611.3266,
#    'eval_samples_per_second': 316.428,
#    'eval_steps_per_second': 2.473,
#    'eval_validity': 0.019246178421327434,
#    'perplexity': 1.7069505934711298},
#   'test': {'eval_accuracy': 0.8132313873172583,
#    'eval_fragmented': 0.971821756225426,
#    'eval_loss': 0.5347881317138672,
#    'eval_runtime': 1316.8372,
#    'eval_samples_per_second': 293.758,
#    'eval_steps_per_second': 1.148,
#    'eval_validity': 0.019724324771477023,
#    'perplexity': 1.7070865264408726},
#   'sampling': {'fragmentation_percentage': 0.14206744057490325,
#    'fragmentation_size': 32.55,
#    'fragmentation_number': 1.14,
#    'novelty': 0.9408834274327466,
#    'validity': 0.9045,
#    'uniqueness': 0.9986733001658374,
#    'internal_diversity': 0.8504783926594751}},
#  'llama_smiles_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7496852227958573,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.6946764588356018,
#    'eval_runtime': 544.5087,
#    'eval_samples_per_second': 355.726,
#    'eval_steps_per_second': 1.39,
#    'eval_validity': 0.003995952420287461,
#    'perplexity': 2.0030608964359837},
#   'test': {'eval_accuracy': 0.7498034141165577,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.6941055655479431,
#    'eval_runtime': 1281.468,
#    'eval_samples_per_second': 302.303,
#    'eval_steps_per_second': 1.181,
#    'eval_validity': 0.003946906492648274,
#    'perplexity': 2.001917688771277},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.6679,
#    'uniqueness': 0.9981,
#    'internal_diversity': 0.37225775028564456}},
#  'llama_safe-hr': {'eval': {'epoch': 9.441087613293051,
#    'eval_accuracy': 0.8055875862052851,
#    'eval_fragmented': 0.9916945107398568,
#    'eval_loss': 0.5716539025306702,
#    'eval_runtime': 673.824,
#    'eval_samples_per_second': 287.427,
#    'eval_steps_per_second': 2.247,
#    'eval_validity': 0.05408545243319995,
#    'perplexity': 1.7711940125720198},
#   'test': {'eval_accuracy': 0.8056831283644342,
#    'eval_fragmented': 0.9908821732387084,
#    'eval_loss': 0.5715288519859314,
#    'eval_runtime': 1336.5676,
#    'eval_samples_per_second': 289.795,
#    'eval_steps_per_second': 1.133,
#    'eval_validity': 0.054932344687102244,
#    'perplexity': 1.7709725376439784},
#   'sampling': {'fragmentation_percentage': 0.25535381750465547,
#    'fragmentation_size': 30.37,
#    'fragmentation_number': 1.26,
#    'novelty': 0.9620267909143856,
#    'validity': 0.8592,
#    'uniqueness': 0.9991852886405959,
#    'internal_diversity': 0.8538165349841668}},
#  'jamba_safe-mmpa_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.736886426635698,
#    'eval_fragmented': 0.9274406332453826,
#    'eval_loss': 0.8035297989845276,
#    'eval_runtime': 343.1619,
#    'eval_samples_per_second': 564.346,
#    'eval_steps_per_second': 2.206,
#    'eval_validity': 0.003914035794322066,
#    'perplexity': 2.23341052147162},
#   'test': {'eval_accuracy': 0.736940988983068,
#    'eval_fragmented': 0.9308996088657105,
#    'eval_loss': 0.8030346035957336,
#    'eval_runtime': 735.4359,
#    'eval_samples_per_second': 526.637,
#    'eval_steps_per_second': 2.057,
#    'eval_validity': 0.003960672126576265,
#    'perplexity': 2.2323048206716667},
#   'sampling': {'fragmentation_percentage': 0.39271781534460337,
#    'fragmentation_size': 26.77,
#    'fragmentation_number': 1.42,
#    'novelty': 0.9915364583333334,
#    'validity': 0.1538,
#    'uniqueness': 0.9986996098829649,
#    'internal_diversity': 0.8410702321790323}},
#  'jamba_safe-rotatable_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.733502908872714,
#    'eval_fragmented': 0.9506172839506173,
#    'eval_loss': 0.783375084400177,
#    'eval_runtime': 379.6904,
#    'eval_samples_per_second': 509.47,
#    'eval_steps_per_second': 1.991,
#    'eval_validity': 0.009212111186356564,
#    'perplexity': 2.1888473572886045},
#   'test': {'eval_accuracy': 0.7334784913512339,
#    'eval_fragmented': 0.9548693586698337,
#    'eval_loss': 0.7831810712814331,
#    'eval_runtime': 832.5514,
#    'eval_samples_per_second': 464.634,
#    'eval_steps_per_second': 1.816,
#    'eval_validity': 0.008706621996112007,
#    'perplexity': 2.188422733378999},
#   'sampling': {'fragmentation_percentage': 0.30405405405405406,
#    'fragmentation_size': 28.31,
#    'fragmentation_number': 1.32,
#    'novelty': 0.981159420289855,
#    'validity': 0.2072,
#    'uniqueness': 0.999034749034749,
#    'internal_diversity': 0.8470884894121969}},
#  'gpt2_safe-rotatable_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7058194846642839,
#    'eval_fragmented': 0.9800936768149883,
#    'eval_loss': 0.8636521697044373,
#    'eval_runtime': 470.7457,
#    'eval_samples_per_second': 410.925,
#    'eval_steps_per_second': 1.606,
#    'eval_validity': 0.004414782801991305,
#    'perplexity': 2.371807137126653},
#   'test': {'eval_accuracy': 0.7058076989130915,
#    'eval_fragmented': 0.9663865546218487,
#    'eval_loss': 0.8630751967430115,
#    'eval_runtime': 946.7021,
#    'eval_samples_per_second': 408.61,
#    'eval_steps_per_second': 1.597,
#    'eval_validity': 0.004614406253877652,
#    'perplexity': 2.3704390632475856},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'jamba_safe-mmpa_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.792454016321269,
#    'eval_fragmented': 0.9722299361288531,
#    'eval_loss': 0.6143069863319397,
#    'eval_runtime': 348.6137,
#    'eval_samples_per_second': 555.52,
#    'eval_steps_per_second': 2.171,
#    'eval_validity': 0.018594251840836094,
#    'perplexity': 1.848375206316415},
#   'test': {'eval_accuracy': 0.7924910810790027,
#    'eval_fragmented': 0.9707261617166406,
#    'eval_loss': 0.6140395998954773,
#    'eval_runtime': 859.5112,
#    'eval_samples_per_second': 450.614,
#    'eval_steps_per_second': 1.76,
#    'eval_validity': 0.018169002447664392,
#    'perplexity': 1.8478810419261245},
#   'sampling': {'fragmentation_percentage': 0.33433776195041776,
#    'fragmentation_size': 28.98,
#    'fragmentation_number': 1.35,
#    'novelty': 0.9659994516040581,
#    'validity': 0.7301,
#    'uniqueness': 0.9990412272291467,
#    'internal_diversity': 0.8521750375494628}},
#  'gpt2_safe-rotatable_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7163104804156403,
#    'eval_fragmented': 0.8916187834357043,
#    'eval_loss': 0.7813165783882141,
#    'eval_runtime': 878.2047,
#    'eval_samples_per_second': 220.269,
#    'eval_steps_per_second': 1.722,
#    'eval_validity': 0.013046434138384744,
#    'perplexity': 2.184346236226179},
#   'test': {'eval_accuracy': 0.7182351608787914,
#    'eval_fragmented': 0.9248924240448559,
#    'eval_loss': 0.7823876142501831,
#    'eval_runtime': 947.2596,
#    'eval_samples_per_second': 408.37,
#    'eval_steps_per_second': 1.596,
#    'eval_validity': 0.01982514373164578,
#    'perplexity': 2.186687002678781},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'llama_smiles': {'eval': {'epoch': 9.440196356084206,
#    'eval_accuracy': 0.8029154172298414,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5175148248672485,
#    'eval_runtime': 569.4954,
#    'eval_samples_per_second': 340.119,
#    'eval_steps_per_second': 2.658,
#    'eval_validity': 0.009551049066578556,
#    'perplexity': 1.6778527062927582},
#   'test': {'eval_accuracy': 0.8029626196436684,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5176146030426025,
#    'eval_runtime': 1289.286,
#    'eval_samples_per_second': 300.47,
#    'eval_steps_per_second': 1.174,
#    'eval_validity': 0.01003892697835784,
#    'perplexity': 1.6780201277266686},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.9811,
#    'uniqueness': 0.9979,
#    'internal_diversity': 0.8127735427711487}},
#  'llama_safe-brics_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8187585150837974,
#    'eval_fragmented': 0.931247963506028,
#    'eval_loss': 0.5196083784103394,
#    'eval_runtime': 629.1167,
#    'eval_samples_per_second': 305.888,
#    'eval_steps_per_second': 1.195,
#    'eval_validity': 0.015947910766528614,
#    'perplexity': 1.6813690603241842},
#   'test': {'eval_accuracy': 0.8187686729438687,
#    'eval_fragmented': 0.9306787038529744,
#    'eval_loss': 0.5192795395851135,
#    'eval_runtime': 1313.501,
#    'eval_samples_per_second': 293.053,
#    'eval_steps_per_second': 1.145,
#    'eval_validity': 0.01611478569906943,
#    'perplexity': 1.6808162517950513},
#   'sampling': {'fragmentation_percentage': 0.12013057671381937,
#    'fragmentation_size': 33.07,
#    'fragmentation_number': 1.12,
#    'novelty': 0.9081487945892877,
#    'validity': 0.919,
#    'uniqueness': 0.9974972796517955,
#    'internal_diversity': 0.847846510182457}},
#  'llama_safe-brics': {'eval': {'epoch': 9.502993442934525,
#    'eval_accuracy': 0.8278072146128335,
#    'eval_fragmented': 0.9315237507711289,
#    'eval_loss': 0.48302868008613586,
#    'eval_runtime': 585.7262,
#    'eval_samples_per_second': 328.548,
#    'eval_steps_per_second': 2.568,
#    'eval_validity': 0.016846896938770207,
#    'perplexity': 1.6209763940880224},
#   'test': {'eval_accuracy': 0.8277841684822576,
#    'eval_fragmented': 0.9310344827586207,
#    'eval_loss': 0.4829130172729492,
#    'eval_runtime': 1301.2798,
#    'eval_samples_per_second': 295.806,
#    'eval_steps_per_second': 1.156,
#    'eval_validity': 0.01702664927804305,
#    'perplexity': 1.620788918240374},
#   'sampling': {'fragmentation_percentage': 0.10176041219407471,
#    'fragmentation_size': 33.24,
#    'fragmentation_number': 1.1,
#    'novelty': 0.9147220131196903,
#    'validity': 0.9316,
#    'uniqueness': 0.9981751824817519,
#    'internal_diversity': 0.846857675218176}},
#  'gpt2_safe-rotatable': {'eval': {'epoch': 9.454476694714948,
#    'eval_accuracy': 0.8003838277112519,
#    'eval_fragmented': 0.9682446339311968,
#    'eval_loss': 0.5717918276786804,
#    'eval_runtime': 418.043,
#    'eval_samples_per_second': 462.73,
#    'eval_steps_per_second': 3.617,
#    'eval_validity': 0.01758158818451104,
#    'perplexity': 1.7714383216161518},
#   'test': {'eval_accuracy': 0.8003058728200829,
#    'eval_fragmented': 0.9700805523590333,
#    'eval_loss': 0.5716715455055237,
#    'eval_runtime': 964.4743,
#    'eval_samples_per_second': 401.081,
#    'eval_steps_per_second': 1.568,
#    'eval_validity': 0.01797162592546635,
#    'perplexity': 1.7712252619791098},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'jamba_safe-recap_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8027703338476954,
#    'eval_fragmented': 0.8019417475728156,
#    'eval_loss': 0.5510175824165344,
#    'eval_runtime': 326.9525,
#    'eval_samples_per_second': 583.002,
#    'eval_steps_per_second': 2.279,
#    'eval_validity': 0.005403590502271607,
#    'perplexity': 1.7350176433354376},
#   'test': {'eval_accuracy': 0.802855253256287,
#    'eval_fragmented': 0.787661406025825,
#    'eval_loss': 0.5512511730194092,
#    'eval_runtime': 715.9762,
#    'eval_samples_per_second': 532.417,
#    'eval_steps_per_second': 2.081,
#    'eval_validity': 0.005485338328112949,
#    'perplexity': 1.7354229744916743},
#   'sampling': {'fragmentation_percentage': 0.05563768310710926,
#    'fragmentation_size': 34.05,
#    'fragmentation_number': 1.06,
#    'novelty': 0.8579330814894766,
#    'validity': 0.7441,
#    'uniqueness': 0.9961026743717243,
#    'internal_diversity': 0.8448174106205494}},
#  'jamba_safe-recap_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7522562370610844,
#    'eval_fragmented': 0.7391304347826086,
#    'eval_loss': 0.6690206527709961,
#    'eval_runtime': 714.0724,
#    'eval_samples_per_second': 266.939,
#    'eval_steps_per_second': 2.087,
#    'eval_validity': 0.0019910494588227887,
#    'perplexity': 1.9523243806003152},
#   'test': {'eval_accuracy': 0.7531033899823562,
#    'eval_fragmented': 0.6459627329192547,
#    'eval_loss': 0.667015016078949,
#    'eval_runtime': 819.7939,
#    'eval_samples_per_second': 464.992,
#    'eval_steps_per_second': 1.818,
#    'eval_validity': 0.0008447053762086895,
#    'perplexity': 1.948412651253029},
#   'sampling': {'fragmentation_percentage': 0.11147433801896045,
#    'fragmentation_size': 33.01,
#    'fragmentation_number': 1.11,
#    'novelty': 0.9088827089808604,
#    'validity': 0.6118,
#    'uniqueness': 0.999182739457339,
#    'internal_diversity': 0.8471965692769128}},
#  'jamba_smiles_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7472038958875639,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.7072277665138245,
#    'eval_runtime': 321.9331,
#    'eval_samples_per_second': 601.665,
#    'eval_steps_per_second': 2.351,
#    'eval_validity': 0.00249359821576078,
#    'perplexity': 2.028360368646096},
#   'test': {'eval_accuracy': 0.7474731738006417,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.706692099571228,
#    'eval_runtime': 803.5909,
#    'eval_samples_per_second': 482.076,
#    'eval_steps_per_second': 1.884,
#    'eval_validity': 0.0026923632909301174,
#    'perplexity': 2.027274134004908},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.5973,
#    'uniqueness': 0.9982,
#    'internal_diversity': 0.29821334662719723}},
#  'llama_safe-recap_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8104526870999101,
#    'eval_fragmented': 0.7821229050279329,
#    'eval_loss': 0.5284607410430908,
#    'eval_runtime': 547.2817,
#    'eval_samples_per_second': 348.292,
#    'eval_steps_per_second': 1.361,
#    'eval_validity': 0.007512564659468875,
#    'perplexity': 1.696319223468624},
#   'test': {'eval_accuracy': 0.8105223989594738,
#    'eval_fragmented': 0.783041537933402,
#    'eval_loss': 0.5286086797714233,
#    'eval_runtime': 1284.1773,
#    'eval_samples_per_second': 296.842,
#    'eval_steps_per_second': 1.16,
#    'eval_validity': 0.007641698015204697,
#    'perplexity': 1.6965701933410142},
#   'sampling': {'fragmentation_percentage': 0.041119166289080196,
#    'fragmentation_size': 34.92,
#    'fragmentation_number': 1.04,
#    'novelty': 0.8553244686896239,
#    'validity': 0.8828,
#    'uniqueness': 0.9967149977344812,
#    'internal_diversity': 0.8466443947960489}},
#  'llama_safe-recap_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7335381929809094,
#    'eval_fragmented': 0.7924528301886793,
#    'eval_loss': 0.763579785823822,
#    'eval_runtime': 557.3626,
#    'eval_samples_per_second': 341.993,
#    'eval_steps_per_second': 1.337,
#    'eval_validity': 0.0022243906533622924,
#    'perplexity': 2.1459445086239284},
#   'test': {'eval_accuracy': 0.7337164111950759,
#    'eval_fragmented': 0.8046242774566474,
#    'eval_loss': 0.7632523775100708,
#    'eval_runtime': 1277.0811,
#    'eval_samples_per_second': 298.492,
#    'eval_steps_per_second': 1.167,
#    'eval_validity': 0.0022691619578276904,
#    'perplexity': 2.145242023556957},
#   'sampling': {'fragmentation_percentage': 0.13871543264942016,
#    'fragmentation_size': 31.6,
#    'fragmentation_number': 1.14,
#    'novelty': 0.942626624831914,
#    'validity': 0.2242,
#    'uniqueness': 0.9950936663693131,
#    'internal_diversity': 0.8479203203108026}},
#  'gpt2_safe-mmpa_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7070849895219179,
#    'eval_fragmented': 0.9068772622573215,
#    'eval_loss': 0.833130955696106,
#    'eval_runtime': 814.9974,
#    'eval_samples_per_second': 237.623,
#    'eval_steps_per_second': 1.856,
#    'eval_validity': 0.007848697565586598,
#    'perplexity': 2.300510271945729},
#   'test': {'eval_accuracy': 0.7000022866742961,
#    'eval_fragmented': 0.9318850418646752,
#    'eval_loss': 0.8386867046356201,
#    'eval_runtime': 952.0743,
#    'eval_samples_per_second': 406.804,
#    'eval_steps_per_second': 1.589,
#    'eval_validity': 0.011409524202959919,
#    'perplexity': 2.3133268994649523},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'gpt2_safe-mmpa_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7152144981220984,
#    'eval_fragmented': 0.981651376146789,
#    'eval_loss': 0.8698237538337708,
#    'eval_runtime': 405.3662,
#    'eval_samples_per_second': 477.746,
#    'eval_steps_per_second': 1.867,
#    'eval_validity': 0.008442544226539022,
#    'perplexity': 2.3864902067069953},
#   'test': {'eval_accuracy': 0.7154092767575142,
#    'eval_fragmented': 0.9856787048567871,
#    'eval_loss': 0.8691853284835815,
#    'eval_runtime': 953.1448,
#    'eval_samples_per_second': 406.348,
#    'eval_steps_per_second': 1.587,
#    'eval_validity': 0.008293141375855908,
#    'perplexity': 2.384967097108678},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'llama_safe-mmpa_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8015290975414578,
#    'eval_fragmented': 0.9882917466410749,
#    'eval_loss': 0.5907636284828186,
#    'eval_runtime': 572.9471,
#    'eval_samples_per_second': 338.01,
#    'eval_steps_per_second': 1.321,
#    'eval_validity': 0.026902541541448503,
#    'perplexity': 1.8053665184469323},
#   'test': {'eval_accuracy': 0.8015919938491007,
#    'eval_fragmented': 0.9863000755857899,
#    'eval_loss': 0.5905625820159912,
#    'eval_runtime': 1333.6812,
#    'eval_samples_per_second': 290.405,
#    'eval_steps_per_second': 1.134,
#    'eval_validity': 0.027327088518698295,
#    'perplexity': 1.805003592370795},
#   'sampling': {'fragmentation_percentage': 0.23699617203332582,
#    'fragmentation_size': 30.89,
#    'fragmentation_number': 1.24,
#    'novelty': 0.9498139167700462,
#    'validity': 0.8882,
#    'uniqueness': 0.9983111911731593,
#    'internal_diversity': 0.8520662181467676}},
#  'jamba_safe-rotatable_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.7951248119450749,
#    'eval_fragmented': 0.9607563325008919,
#    'eval_loss': 0.5928866863250732,
#    'eval_runtime': 339.7401,
#    'eval_samples_per_second': 569.379,
#    'eval_steps_per_second': 2.225,
#    'eval_validity': 0.014490206316137738,
#    'perplexity': 1.809203487604574},
#   'test': {'eval_accuracy': 0.7948983599581629,
#    'eval_fragmented': 0.9654733781573687,
#    'eval_loss': 0.5929729342460632,
#    'eval_runtime': 857.3907,
#    'eval_samples_per_second': 451.174,
#    'eval_steps_per_second': 1.763,
#    'eval_validity': 0.01422581378996567,
#    'perplexity': 1.8093595343732856},
#   'sampling': {'fragmentation_percentage': 0.23344413193556635,
#    'fragmentation_size': 30.72,
#    'fragmentation_number': 1.24,
#    'novelty': 0.9578745198463509,
#    'validity': 0.7822,
#    'uniqueness': 0.9984658655075428,
#    'internal_diversity': 0.8525017124113934}},
#  'llama_safe-hr_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7271515347646458,
#    'eval_fragmented': 0.9883743091290261,
#    'eval_loss': 0.8136702179908752,
#    'eval_runtime': 581.2084,
#    'eval_samples_per_second': 333.228,
#    'eval_steps_per_second': 1.302,
#    'eval_validity': 0.02709177746224345,
#    'perplexity': 2.2561734577730306},
#   'test': {'eval_accuracy': 0.727212164574836,
#    'eval_fragmented': 0.9884785819793205,
#    'eval_loss': 0.8133459091186523,
#    'eval_runtime': 1350.7045,
#    'eval_samples_per_second': 286.762,
#    'eval_steps_per_second': 1.121,
#    'eval_validity': 0.026217885994149707,
#    'perplexity': 2.255441879338502},
#   'sampling': {'fragmentation_percentage': 0.4098784587535557,
#    'fragmentation_size': 27.26,
#    'fragmentation_number': 1.43,
#    'novelty': 0.9930142302716688,
#    'validity': 0.3867,
#    'uniqueness': 0.9994828032066201,
#    'internal_diversity': 0.8505513726586952}},
#  'llama_safe-recap_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7624324823592802,
#    'eval_fragmented': 0.7415630550621669,
#    'eval_loss': 0.6338496208190918,
#    'eval_runtime': 1112.2607,
#    'eval_samples_per_second': 171.375,
#    'eval_steps_per_second': 1.34,
#    'eval_validity': 0.002953783518622477,
#    'perplexity': 1.8848525986110123},
#   'test': {'eval_accuracy': 0.7624076658417273,
#    'eval_fragmented': 0.7651245551601423,
#    'eval_loss': 0.630549430847168,
#    'eval_runtime': 1296.274,
#    'eval_samples_per_second': 294.072,
#    'eval_steps_per_second': 1.149,
#    'eval_validity': 0.002211449168148836,
#    'perplexity': 1.8786424798886183},
#   'sampling': {'fragmentation_percentage': 0.07199504337050805,
#    'fragmentation_size': 34.09,
#    'fragmentation_number': 1.07,
#    'novelty': 0.9021847070506455,
#    'validity': 0.807,
#    'uniqueness': 0.9982651796778191,
#    'internal_diversity': 0.8490132421193617}},
#  'jamba_safe-brics_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.8151053524952943,
#    'eval_fragmented': 0.8972565895642819,
#    'eval_loss': 0.5291650295257568,
#    'eval_runtime': 336.9044,
#    'eval_samples_per_second': 571.198,
#    'eval_steps_per_second': 2.232,
#    'eval_validity': 0.009660204012700128,
#    'perplexity': 1.6975143423654748},
#   'test': {'eval_accuracy': 0.8150495630719082,
#    'eval_fragmented': 0.8930627913353442,
#    'eval_loss': 0.5289665460586548,
#    'eval_runtime': 747.5747,
#    'eval_samples_per_second': 514.9,
#    'eval_steps_per_second': 2.012,
#    'eval_validity': 0.009474548354748705,
#    'perplexity': 1.6971774472685062},
#   'sampling': {'fragmentation_percentage': 0.16173620979201653,
#    'fragmentation_size': 31.91,
#    'fragmentation_number': 1.16,
#    'novelty': 0.9091262639357013,
#    'validity': 0.7741,
#    'uniqueness': 0.996512078542824,
#    'internal_diversity': 0.8475978756706573}},
#  'llama_smiles_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.7933744825721122,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5506685376167297,
#    'eval_runtime': 561.7902,
#    'eval_samples_per_second': 344.784,
#    'eval_steps_per_second': 1.347,
#    'eval_validity': 0.008657896910622832,
#    'perplexity': 1.7344121501277372},
#   'test': {'eval_accuracy': 0.793363541386638,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5507580041885376,
#    'eval_runtime': 1295.3412,
#    'eval_samples_per_second': 299.066,
#    'eval_steps_per_second': 1.169,
#    'eval_validity': 0.008805034693540393,
#    'perplexity': 1.7345673289784673},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.9632,
#    'uniqueness': 0.9968,
#    'internal_diversity': 0.7838334311608887}},
#  'jamba_smiles_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.789602547843723,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5682905912399292,
#    'eval_runtime': 336.4201,
#    'eval_samples_per_second': 575.756,
#    'eval_steps_per_second': 2.25,
#    'eval_validity': 0.005709978523046423,
#    'perplexity': 1.7652469422818065},
#   'test': {'eval_accuracy': 0.7895837172924453,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5683209896087646,
#    'eval_runtime': 731.2985,
#    'eval_samples_per_second': 529.732,
#    'eval_steps_per_second': 2.07,
#    'eval_validity': 0.005815814472162564,
#    'perplexity': 1.7653006037250496},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.931,
#    'uniqueness': 0.9958,
#    'internal_diversity': 0.7311297459954833}},
#  'gpt2_safe-recap_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7504584455666939,
#    'eval_fragmented': 0.7545748116254036,
#    'eval_loss': 0.67108553647995,
#    'eval_runtime': 791.5224,
#    'eval_samples_per_second': 240.819,
#    'eval_steps_per_second': 1.882,
#    'eval_validity': 0.0024370025655419906,
#    'perplexity': 1.956359868381041},
#   'test': {'eval_accuracy': 0.7495959275434123,
#    'eval_fragmented': 0.7231638418079096,
#    'eval_loss': 0.6739839911460876,
#    'eval_runtime': 927.9544,
#    'eval_samples_per_second': 410.794,
#    'eval_steps_per_second': 1.606,
#    'eval_validity': 0.0009286512521052052,
#    'perplexity': 1.9620385144437398},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'jamba_safe-hr': {'eval': {'epoch': 9.441087613293051,
#    'eval_accuracy': 0.7879051098330005,
#    'eval_fragmented': 0.9871205151793928,
#    'eval_loss': 0.6229240894317627,
#    'eval_runtime': 401.6375,
#    'eval_samples_per_second': 482.213,
#    'eval_steps_per_second': 3.77,
#    'eval_validity': 0.02806247579708274,
#    'perplexity': 1.8643716686349747},
#   'test': {'eval_accuracy': 0.7880445766053163,
#    'eval_fragmented': 0.9840072694229896,
#    'eval_loss': 0.6226335167884827,
#    'eval_runtime': 756.1549,
#    'eval_samples_per_second': 512.238,
#    'eval_steps_per_second': 2.002,
#    'eval_validity': 0.028412391468795425,
#    'perplexity': 1.8638300119302842},
#   'sampling': {'fragmentation_percentage': 0.34936965657151137,
#    'fragmentation_size': 28.68,
#    'fragmentation_number': 1.36,
#    'novelty': 0.9820289855072464,
#    'validity': 0.6901,
#    'uniqueness': 0.9998550934647152,
#    'internal_diversity': 0.856314405668531}},
#  'jamba_safe-brics_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.7565240930248736,
#    'eval_fragmented': 0.9099099099099099,
#    'eval_loss': 0.7196334004402161,
#    'eval_runtime': 396.8474,
#    'eval_samples_per_second': 484.919,
#    'eval_steps_per_second': 1.895,
#    'eval_validity': 0.0017304184702685006,
#    'perplexity': 2.053680194369411},
#   'test': {'eval_accuracy': 0.7566852133352839,
#    'eval_fragmented': 0.9407514450867052,
#    'eval_loss': 0.7191964983940125,
#    'eval_runtime': 842.9735,
#    'eval_samples_per_second': 456.629,
#    'eval_steps_per_second': 1.784,
#    'eval_validity': 0.001797748138603264,
#    'perplexity': 2.052783133268428},
#   'sampling': {'fragmentation_percentage': 0.25494276795005205,
#    'fragmentation_size': 28.91,
#    'fragmentation_number': 1.26,
#    'novelty': 0.9483298538622129,
#    'validity': 0.1922,
#    'uniqueness': 0.9968782518210197,
#    'internal_diversity': 0.8373608097501699}},
#  'gpt2_safe-hr_10000': {'eval': {'epoch': 509.5541401273885,
#    'eval_accuracy': 0.6981299163153031,
#    'eval_fragmented': 0.9899928520371694,
#    'eval_loss': 0.912924587726593,
#    'eval_runtime': 408.2113,
#    'eval_samples_per_second': 474.448,
#    'eval_steps_per_second': 1.854,
#    'eval_validity': 0.014446882664257131,
#    'perplexity': 2.4915987874101826},
#   'test': {'eval_accuracy': 0.6981860516426929,
#    'eval_fragmented': 0.9878201683682608,
#    'eval_loss': 0.9125735759735107,
#    'eval_runtime': 974.9033,
#    'eval_samples_per_second': 397.302,
#    'eval_steps_per_second': 1.553,
#    'eval_validity': 0.014414028311702394,
#    'perplexity': 2.490724360427888},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'gpt2_safe-hr_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.6788907274330976,
#    'eval_fragmented': 0.9457900807381776,
#    'eval_loss': 0.9011842608451843,
#    'eval_runtime': 821.4183,
#    'eval_samples_per_second': 235.781,
#    'eval_steps_per_second': 1.843,
#    'eval_validity': 0.013430096117354566,
#    'perplexity': 2.4625176482616435},
#   'test': {'eval_accuracy': 0.6761353193279728,
#    'eval_fragmented': 0.9669962917181706,
#    'eval_loss': 0.9070032238960266,
#    'eval_runtime': 970.8791,
#    'eval_samples_per_second': 398.949,
#    'eval_steps_per_second': 1.559,
#    'eval_validity': 0.020886528576333937,
#    'perplexity': 2.4768887192838194},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'jamba_safe-brics_augmentation_100000': {'eval': {'epoch': 63.97952655150352,
#    'eval_accuracy': 0.7503719199813345,
#    'eval_fragmented': 0.8097199341021417,
#    'eval_loss': 0.6820030212402344,
#    'eval_runtime': 666.3025,
#    'eval_samples_per_second': 288.816,
#    'eval_steps_per_second': 2.257,
#    'eval_validity': 0.009464091283525154,
#    'perplexity': 1.9778354135904281},
#   'test': {'eval_accuracy': 0.7482725231170181,
#    'eval_fragmented': 0.8141350210970464,
#    'eval_loss': 0.6830307245254517,
#    'eval_runtime': 832.9683,
#    'eval_samples_per_second': 462.114,
#    'eval_steps_per_second': 1.806,
#    'eval_validity': 0.012314055169045478,
#    'perplexity': 1.9798690863696995},
#   'sampling': {'fragmentation_percentage': 0.2303370786516854,
#    'fragmentation_size': 30.78,
#    'fragmentation_number': 1.24,
#    'novelty': 0.9616465531492808,
#    'validity': 0.6052,
#    'uniqueness': 0.9995042961004627,
#    'internal_diversity': 0.8523362302008457}},
#  'gpt2_safe-mmpa_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.796417875349553,
#    'eval_fragmented': 0.9842969307637401,
#    'eval_loss': 0.6017336249351501,
#    'eval_runtime': 482.121,
#    'eval_samples_per_second': 401.688,
#    'eval_steps_per_second': 1.57,
#    'eval_validity': 0.028937013972797968,
#    'perplexity': 1.8252804107090737},
#   'test': {'eval_accuracy': 0.7964801309138859,
#    'eval_fragmented': 0.9846467873624423,
#    'eval_loss': 0.6014834046363831,
#    'eval_runtime': 970.2968,
#    'eval_samples_per_second': 399.164,
#    'eval_steps_per_second': 1.559,
#    'eval_validity': 0.029093124851539344,
#    'perplexity': 1.8248237456351906},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}},
#  'jamba_safe-rotatable': {'eval': {'epoch': 9.454476694714948,
#    'eval_accuracy': 0.8012489890688999,
#    'eval_fragmented': 0.9233449477351916,
#    'eval_loss': 0.571641206741333,
#    'eval_runtime': 355.5659,
#    'eval_samples_per_second': 544.037,
#    'eval_steps_per_second': 4.252,
#    'eval_validity': 0.016320221669656382,
#    'perplexity': 1.7711715260087035},
#   'test': {'eval_accuracy': 0.8011091027344861,
#    'eval_fragmented': 0.927062138049773,
#    'eval_loss': 0.5717857480049133,
#    'eval_runtime': 867.8767,
#    'eval_samples_per_second': 445.722,
#    'eval_steps_per_second': 1.742,
#    'eval_validity': 0.01651621375687637,
#    'perplexity': 1.7714275518817961},
#   'sampling': {'fragmentation_percentage': 0.24552845528455283,
#    'fragmentation_size': 30.4,
#    'fragmentation_number': 1.25,
#    'novelty': 0.9615480961923848,
#    'validity': 0.7995,
#    'uniqueness': 0.9986241400875547,
#    'internal_diversity': 0.8520744510737097}},
#  'gpt2_smiles_100000': {'eval': {'epoch': 127.8772378516624,
#    'eval_accuracy': 0.7898000551090675,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5616481304168701,
#    'eval_runtime': 393.857,
#    'eval_samples_per_second': 491.793,
#    'eval_steps_per_second': 1.922,
#    'eval_validity': 0.0077389311085412195,
#    'perplexity': 1.7535602159061165},
#   'test': {'eval_accuracy': 0.7899791937004019,
#    'eval_fragmented': 0.0,
#    'eval_loss': 0.5614233613014221,
#    'eval_runtime': 926.8951,
#    'eval_samples_per_second': 417.946,
#    'eval_steps_per_second': 1.633,
#    'eval_validity': 0.00752209648108376,
#    'perplexity': 1.753166114020128},
#   'sampling': {'novelty': 1.0,
#    'validity': 0.0055,
#    'uniqueness': 1.0,
#    'internal_diversity': 2.5718291015608408e-05}},
#  'gpt2_safe-recap': {'eval': {'epoch': 9.596928982725528,
#    'eval_accuracy': 0.8071581535657703,
#    'eval_fragmented': 0.8083989501312336,
#    'eval_loss': 0.5288418531417847,
#    'eval_runtime': 394.0763,
#    'eval_samples_per_second': 483.698,
#    'eval_steps_per_second': 3.781,
#    'eval_validity': 0.005996411596210142,
#    'perplexity': 1.6969658344557437},
#   'test': {'eval_accuracy': 0.8072712492922001,
#    'eval_fragmented': 0.8137988362427265,
#    'eval_loss': 0.5288832187652588,
#    'eval_runtime': 936.2296,
#    'eval_samples_per_second': 407.163,
#    'eval_steps_per_second': 1.591,
#    'eval_validity': 0.006311680543969276,
#    'perplexity': 1.6970360319573718},
#   'sampling': {'fragmentation_percentage': 0.0,
#    'fragmentation_size': nan,
#    'fragmentation_number': nan,
#    'novelty': 0.0,
#    'validity': 0.0,
#    'uniqueness': 0.0,
#    'internal_diversity': 0.0}}}

# %%
data_dir="/mnt/ps/home/CORP/yassir.elmesbahi/ondemand/data/moses"
output_dir="/mnt/ps/home/CORP/yassir.elmesbahi/sandbox/models"

dic_eval = {'Model':[],'Loss':[],'Perplexity':[],'Accuracy':[],'Validity':[],'Frag. percent.':[],'Train. set':[],'Eval. split':[]}
dic_sampling = {'Model':[],'Train. set':[], 'Gen. samples':[],'Validity':[],'Uniqueness':[], 'Novelty':[],'Internal diversity':[],
                'Frag. percent.':[],'Frag. size':[], 'Frag. number':[]}
dic_ds = {'Dataset':[], 'Train. size':[], 'Valid. size': [], 'Test size': [], 'Validity':[], 'Uniqueness':[], 'Internal diversity': [], 
          'Frag. percent.':[],'Frag. size':[], 'Frag. number':[]}
tmp = {}
with open(os.path.join(data_dir, "global_dic"), "r") as fp:
    tmp=json.load(fp)

for ds_name, values in tmp.items():
    dic_ds['Dataset'].append(ds_name)
    dic_ds['Train. size'].append(values['train_size'])
    dic_ds['Valid. size'].append(values['valid_size'])
    dic_ds['Test size'].append(values['test_size'])
    dic_ds['Validity'].append(values['train_validity'])
    dic_ds['Uniqueness'].append(values['train_uniqueness'])
    dic_ds['Internal diversity'].append(values['train_internal_diversity'])
    dic_ds['Frag. percent.'].append(values['train_fragmentation']['percentage'])
    dic_ds['Frag. size'].append(values['train_fragmentation']['size'])
    dic_ds['Frag. number'].append(values['train_fragmentation']['number'])


### Validation / Test results 
for name, values in global_dic.items():
    model_name = name.split('_')[0]
    for k,v in {'eval':'Valid', 'test':'Test'}.items():
        dic_eval['Model'].append(model_name)
        dic_eval['Eval. split'].append(v)
        #print(f"{model_name}, {k}, {v}, {values}")
        dic_eval['Loss'].append(values[k]['eval_loss'])
        dic_eval['Perplexity'].append(values[k]['perplexity'])
        dic_eval['Accuracy'].append(values[k]['eval_accuracy'])
        dic_eval['Validity'].append(values[k]['eval_validity'])
        dic_eval['Frag. percent.'].append(values[k]['eval_fragmented'])
        dic_eval['Train. set'].append(name.partition('_')[2])

### Sampling results
for i, (name, values) in enumerate(global_dic.items()):
    model_name = name.split('_')[0]
    dic_sampling['Model'].append(model_name)
    dic_sampling['Train. set'].append(name.partition('_')[2])
    dic_sampling['Gen. samples'].append(10000)
    dic_sampling['Validity'].append(values['sampling']['validity'])
    dic_sampling['Uniqueness'].append(values['sampling']['uniqueness'])
    dic_sampling['Novelty'].append(values['sampling']['novelty'])
    dic_sampling['Internal diversity'].append(values['sampling']['internal_diversity'])
    if 'smiles' not in name:
        for k,v in {'Frag. percent.': 'fragmentation_percentage', 'Frag. size': 'fragmentation_size', 'Frag. number': 'fragmentation_number'}.items():
            value = values['sampling'][v]
            #print(value, type(value))
            dic_sampling[k].append(value if not math.isnan(value) else 0.0)
    else:
        dic_sampling['Frag. percent.'].append(0.0)
        dic_sampling['Frag. size'].append(0.0)
        dic_sampling['Frag. number'].append(0.0)       


df_eval = pd.DataFrame.from_dict(dic_eval)
df_sampling = pd.DataFrame.from_dict(dic_sampling)
df_ds = pd.DataFrame.from_dict(dic_ds)

df_ds.to_csv(os.path.join(output_dir, 'datasets_df.csv'))
df_eval.to_csv(os.path.join(output_dir, 'eval_df.csv'))
df_sampling.to_csv(os.path.join(output_dir, 'sampling_df.csv'))

# %%
df_eval
# Out:
#      Model      Loss  Perplexity  Accuracy  Validity  Frag. percent.
# 0    jamba  0.506562    1.659576  0.820654  0.013901        0.903551  \
# 1    jamba  0.506436    1.659366  0.820670  0.014153        0.895742
# 2    llama  0.572910    1.773420  0.803708  0.017949        0.967166
# 3    llama  0.572686    1.773023  0.803620  0.018114        0.964750
# 4    jamba  0.782357    2.186619  0.730571  0.001689        0.881988
# ..     ...       ...         ...       ...       ...             ...
# 133  jamba  0.571786    1.771428  0.801109  0.016516        0.927062
# 134   gpt2  0.561648    1.753560  0.789800  0.007739        0.000000
# 135   gpt2  0.561423    1.753166  0.789979  0.007522        0.000000
# 136   gpt2  0.528842    1.696966  0.807158  0.005996        0.808399
# 137   gpt2  0.528883    1.697036  0.807271  0.006312        0.813799
#
#                 Train. set Eval. split
# 0               safe-brics       Valid
# 1               safe-brics        Test
# 2    safe-rotatable_100000       Valid
# 3    safe-rotatable_100000        Test
# 4         safe-recap_10000       Valid
# ..                     ...         ...
# 133         safe-rotatable        Test
# 134          smiles_100000       Valid
# 135          smiles_100000        Test
# 136             safe-recap       Valid
# 137             safe-recap        Test
#
# [138 rows x 8 columns]

# %%
df_ds
# Out:
#                      Dataset  Train. size  Valid. size  Test size  Validity
# 0                 safe-brics      1346886       192439     384926       1.0  \
# 1           safe-brics_10000        10000       192439     384926       1.0
# 2          safe-brics_100000       100000       192439     384926       1.0
# 3       safe-brics_augmented       590544       192439     384926       1.0
# 4                    safe-hr      1355687       193675     387331       1.0
# 5              safe-hr_10000        10000       193675     387331       1.0
# 6             safe-hr_100000       100000       193675     387331       1.0
# 7          safe-hr_augmented       599556       193675     387331       1.0
# 8                  safe-mmpa      1355609       193662     387308       1.0
# 9            safe-mmpa_10000        10000       193662     387308       1.0
# 10          safe-mmpa_100000       100000       193662     387308       1.0
# 11       safe-mmpa_augmented       598820       193662     387308       1.0
# 12                safe-recap      1333669       190614     381198       1.0
# 13          safe-recap_10000        10000       190614     381198       1.0
# 14         safe-recap_100000       100000       190614     381198       1.0
# 15      safe-recap_augmented       582792       190614     381198       1.0
# 16            safe-rotatable      1353839       193441     386832       1.0
# 17      safe-rotatable_10000        10000       193441     386832       1.0
# 18     safe-rotatable_100000       100000       193441     386832       1.0
# 19  safe-rotatable_augmented       595124       193441     386832       1.0
# 20                    smiles      1355874       193696     387392       1.0
# 21              smiles_10000        10000       193696     387392       1.0
# 22             smiles_100000       100000       193696     387392       1.0
# 23          smiles_augmented       100000       193696     387392       1.0
#
#     Uniqueness  Internal diversity  Frag. percent.  Frag. size  Frag. number
# 0      1.00000            0.855829             1.0        8.04          5.41
# 1      1.00000            0.855759             1.0        8.09          5.40
# 2      1.00000            0.856046             1.0        8.04          5.41
# 3      0.81322            0.855122             1.0        7.89          5.47
# 4      1.00000            0.856327             1.0        5.92          8.72
# 5      1.00000            0.856179             1.0        5.91          8.73
# 6      1.00000            0.856444             1.0        5.93          8.70
# 7      0.81374            0.856623             1.0        5.92          8.71
# 8      1.00000            0.856501             1.0        6.43          7.54
# 9      1.00000            0.855480             1.0        6.43          7.51
# 10     1.00000            0.856075             1.0        6.42          7.55
# 11     0.81414            0.856643             1.0        6.39          7.55
# 12     1.00000            0.855450             1.0        9.59          4.64
# 13     1.00000            0.855371             1.0        9.59          4.64
# 14     1.00000            0.855291             1.0        9.60          4.64
# 15     0.81100            0.853382             1.0        9.35          4.72
# 16     1.00000            0.856278             1.0        7.09          6.35
# 17     1.00000            0.856969             1.0        7.16          6.33
# 18     1.00000            0.856414             1.0        7.11          6.34
# 19     0.81378            0.855716             1.0        7.02          6.38
# 20     1.00000            0.856528             0.0        0.00          0.00
# 21     1.00000            0.856911             0.0        0.00          0.00
# 22     1.00000            0.856575             0.0        0.00          0.00
# 23     1.00000            0.856152             0.0        0.00          0.00

# %%
df_sampling
# Out:
#     Model                      Train. set  Gen. samples  Validity  Uniqueness
# 0   jamba                      safe-brics         10000    0.8002    0.999000  \
# 1   llama           safe-rotatable_100000         10000    0.8742    0.998055
# 2   jamba                safe-recap_10000         10000    0.1678    0.996424
# 3    gpt2                         safe-hr         10000    0.0000    0.000000
# 4   llama            safe-rotatable_10000         10000    0.4649    1.000000
# ..    ...                             ...           ...       ...         ...
# 64  jamba  safe-brics_augmentation_100000         10000    0.6052    0.999504
# 65   gpt2                safe-mmpa_100000         10000    0.0000    0.000000
# 66  jamba                  safe-rotatable         10000    0.7995    0.998624
# 67   gpt2                   smiles_100000         10000    0.0055    1.000000
# 68   gpt2                      safe-recap         10000    0.0000    0.000000
#
#      Novelty  Internal diversity  Frag. percent.  Frag. size  Frag. number
# 0   0.917938            0.847331        0.164334       31.84          1.17
# 1   0.942808            0.849866        0.150309       32.57          1.15
# 2   0.923445            0.834826        0.095948       30.69          1.10
# 3   0.000000            0.000000        0.000000        0.00          0.00
# 4   0.984943            0.847322        0.294257       29.12          1.30
# ..       ...                 ...             ...         ...           ...
# 64  0.961647            0.852336        0.230337       30.78          1.24
# 65  0.000000            0.000000        0.000000        0.00          0.00
# 66  0.961548            0.852074        0.245528       30.40          1.25
# 67  1.000000            0.000026        0.000000        0.00          0.00
# 68  0.000000            0.000000        0.000000        0.00          0.00
#
# [69 rows x 10 columns]

# %%
global_map = {
    "eval_loss":"Loss",
    "perplexity":"Perplexity",
    "eval_accuracy":"Accuracy",
    "eval_fragmented":"Fragmentation percentage",
    "eval_validity":"Validity",
    "validity":"Validity",
    "uniqueness":"Uniqueness",
    "novelty":"Novelty",
    "internal_diversity":"Internal diversity",
    "fragmentation_percentage":"Fragmentation percentage",
    "fragmentation_size":"Fragmentation size",
    "fragmentation_number":"Fragmentation number",
    
}    
with open(f'{PROJECT_DIR}/results.txt', 'w') as f:
    for model, values in global_dic.items():
        #if "jamba" in model:
        #    continue
        print(f"###### Processing model {model} ::", file=f)
        for key in ["eval", "test"]:
            print(f"#### {'Eval' if key=='eval' else 'Test'} results ::", file=f)
            for sub_key in ["eval_loss", "perplexity", "eval_accuracy", "eval_validity", "eval_fragmented"]:  
                value = values[key][sub_key] if values[key][sub_key] is not None else 0.0
                if sub_key in {'eval_loss', 'perplexity'}:
                    print(f">> {global_map[sub_key]} == {np.round(value, 4)}", file=f)
                else:
                    print(f">> {global_map[sub_key]} == {np.round(value * 100., 2)}", file=f)
            print(f"\n", file=f)
        print(f"#### Sampling results ::", file=f)
        key = 'sampling'
        for sub_key in ["validity", "uniqueness", "novelty", "internal_diversity"]:
            value = values[key][sub_key] if values[key][sub_key] is not None else 0.0
            print(f">> {global_map[sub_key]} == {np.round(value * 100., 2)}", file=f)
        if "smiles" in model:
            continue
        value = values[key]["fragmentation_percentage"] if values[key]["fragmentation_percentage"] is not None else 0.0
        print(f">> {global_map['fragmentation_percentage']} == {np.round(value * 100., 2)}", file=f)
        for sub_key in ["fragmentation_size", "fragmentation_number"]:
            value = values[key][sub_key] if values[key][sub_key] is not None else 0.0
            print(f">> {global_map[sub_key]} == {np.round(value, 2)}", file=f)
        print(f"\n\n", file=f)
